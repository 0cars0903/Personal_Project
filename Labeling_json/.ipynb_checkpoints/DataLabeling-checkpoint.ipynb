# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
DIR = "C:/Users/piai/Desktop/work/test/original/"

# %%
name = "L-210827_G02_L_UA-20_001_0025"
img = cv2.imread(DIR + name + ".jpg")
cvt_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

class_id = "WO-01"
x = 832
y = 529
w = 265
h = 426
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,(255,0,0),3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), (255, 0, 0), 5) #(x,y) 좌표

class_id = "UA-20"
x = 702
y = 270
w = 414
h = 708
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,(255,255,0),3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), (255, 255, 0), 5) #(x,y) 좌표

class_id = "WO-08"
points = np.array([[857.36115643818, 683.6358000784], 
                   [831.24943381792, 689.74830295591],
                   [833.38846380677, 715.7478764242], 
                   [825.67754919205,736.74764453889],
                   [823.59603763401,763.39702761871],
                   [801.18918088969,765.34128904066],
                   [777.22122323179,767.80598292292],
                   [772.99840450615,44.63402680074],
                   [772.8790316534,725.35063719572],
                   [769.62437554227,707.22526150549],
                   [747.63556949292,700.0281376898],
                   [740.08552332828,690.83786527543],
                   [733.31173927078,675.57965316897],
                   [754.59334471903,672.94321761071],
                   [763.01171685335,661.03166798436],
                   [762.62061942388,638.99110124319],
                   [783.67792707605,650.73884603669],
                   [801.29656362777,643.08242260954],
                   [829.54459204805,652.89514943955],
                   [849.29942364812,648.84415449753],
                   [852.43897540362,618.77339343787],
                   [862.67868731295,637.08066753287],
                   [863.55126966159,649.66356670549],
                   [870.16687132129,677.09499410935],
                   [857.36115643818,683.6358000784]], np.int32)
cv2.putText(cvt_img, class_id, (860, 770), cv2.FONT_HERSHEY_SIMPLEX,1.0,(0,255,255),3)
cv2.polylines(cvt_img, [points], True, (0, 255, 255), 5) #(x,y) 좌표
plt.imshow(cvt_img)

cvt_img = cv2.cvtColor(cvt_img, cv2.COLOR_RGB2BGR)
cv2.imwrite(name+'_label'+'.jpg', cvt_img)
# Out:
# True

# %%
name = "L-211029_G12_E_UA-07_001_0089"
img = cv2.imread(DIR + name + ".jpg")
cvt_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

class_id = "WO-02"
x = 985
y = 167
w = 196
h = 433
color = (255,0,0)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-03"
x = 1014
y = 560
w = 224
h = 143
color = (255,255,0)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-03"
x = 1107
y = 603
w = 175
h = 115
color = (255,255,0)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-03"
x = 805
y = 547
w = 158
h = 87
color = (255,255,0)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-02"
x = 10
y = 208
w = 1014
h = 283
color = (0,0,255)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-07"
x = 1275
y = 170
w = 235
h = 263
color = (255,0,255)
cv2.putText(cvt_img, class_id, (int(x+0.5*w), y-15), cv2.FONT_HERSHEY_SIMPLEX,1.0,color,3)
cv2.rectangle(cvt_img, (x, y), (x+w, y+h), color, 5) #(x,y) 좌표

class_id = "SO-13"
polygon = [
                    [
                        109.4393807315,
                        598.09674898913
                    ],
                    [
                        292.61766422752,
                        733.80441376947
                    ],
                    [
                        415.14662058689,
                        834.11475214635
                    ],
                    [
                        548.29220621815,
                        925.32513312102
                    ],
                    [
                        589.25605517757,
                        958.64185771488
                    ],
                    [
                        791.41067503415,
                        1070.7086951036
                    ],
                    [
                        1173.8734401412,
                        965.78300553882
                    ],
                    [
                        1745.6555683409,
                        817.72131163568
                    ],
                    [
                        1918.7772772631,
                        753.44872866783
                    ],
                    [
                        1403.908852613,
                        652.18310798229
                    ],
                    [
                        878.97534105106,
                        542.76957492738
                    ],
                    [
                        494.20736089128,
                        570.43316195826
                    ],
                    [
                        109.4393807315,
                        598.09674898913
                    ]
                ]
points = np.array(polygon, np.int32)
cv2.putText(cvt_img, class_id, (860, 770), cv2.FONT_HERSHEY_SIMPLEX,1.0,(0,255,255),3)
cv2.polylines(cvt_img, [points], True, (0, 255, 255), 5) #(x,y) 좌표
plt.imshow(cvt_img)

cvt_img = cv2.cvtColor(cvt_img, cv2.COLOR_RGB2BGR)
cv2.imwrite(name+'_label'+'.jpg', cvt_img)
# Out:
# True
